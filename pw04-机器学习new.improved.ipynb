# %% [markdown]
# # Table of Contents
#  <p>

# %%
import pandas as pd

audit = pd.read_csv(r'audit_risk.csv')
names = ['Sector_score','LOCATION_ID','PARA_A','Score_A','Risk_A','PARA_B','Score_B','Risk_B','TOTAL	numbers	Score_B','Risk_C','oney_Value','Score_MV','Risk_D','District_Loss','PROB','RiSk_E','History','Prob','Risk_F','Score','Inherent_Risk','CONTROL_RISK','Detection_Risk','Audit_Risk','Risk']

# %%
audit.head()
# Out:
#    Sector_score LOCATION_ID  PARA_A  Score_A  Risk_A  PARA_B  Score_B  Risk_B  \
# 0          3.89          23    4.18      0.6   2.508    2.50      0.2   0.500
# 1          3.89           6    0.00      0.2   0.000    4.83      0.2   0.966
# 2          3.89           6    0.51      0.2   0.102    0.23      0.2   0.046
# 3          3.89           6    0.00      0.2   0.000   10.80      0.6   6.480
# 4          3.89           6    0.00      0.2   0.000    0.08      0.2   0.016
#
#    TOTAL  numbers  ...   RiSk_E  History  Prob  Risk_F  Score  Inherent_Risk  \
# 0   6.68      5.0  ...      0.4        0   0.2     0.0    2.4          8.574
# 1   4.83      5.0  ...      0.4        0   0.2     0.0    2.0          2.554
# 2   0.74      5.0  ...      0.4        0   0.2     0.0    2.0          1.548
# 3  10.80      6.0  ...      0.4        0   0.2     0.0    4.4         17.530
# 4   0.08      5.0  ...      0.4        0   0.2     0.0    2.0          1.416
#
# ...

# %%
audit.describe().transpose()
# Out:
#                 count       mean        std   min     25%     50%      75%  \
# Sector_score    776.0  20.184536  24.319017  1.85  2.3700  3.8900  55.5700
# PARA_A          776.0   2.450194   5.678870  0.00  0.2100  0.8750   2.4800
# Score_A         776.0   0.351289   0.174055  0.20  0.2000  0.2000   0.6000
# Risk_A          776.0   1.351029   3.440447  0.00  0.0420  0.1750   1.4880
# PARA_B          776.0  10.799988  50.083624  0.00  0.0000  0.4050   4.1600
# Score_B         776.0   0.313144   0.169804  0.20  0.2000  0.2000   0.4000
# Risk_B          776.0   6.334008  30.072845  0.00  0.0000  0.0810   1.8405
# TOTAL           776.0  13.218481  51.312829  0.00  0.5375  1.3700   7.7075
# numbers         776.0   5.067655   0.264449  5.00  5.0000  5.0000   5.0000
# Score_B.1       776.0   0.223711   0.080352  0.20  0.2000  0.2000   0.2000
# Risk_C          776.0   1.152964   0.537417  1.00  1.0000  1.0000   1.0000
# ...

# %%
audit.describe()
# Out:
#        Sector_score      PARA_A     Score_A      Risk_A       PARA_B  \
# count    776.000000  776.000000  776.000000  776.000000   776.000000
# mean      20.184536    2.450194    0.351289    1.351029    10.799988
# std       24.319017    5.678870    0.174055    3.440447    50.083624
# min        1.850000    0.000000    0.200000    0.000000     0.000000
# 25%        2.370000    0.210000    0.200000    0.042000     0.000000
# 50%        3.890000    0.875000    0.200000    0.175000     0.405000
# 75%       55.570000    2.480000    0.600000    1.488000     4.160000
# max       59.850000   85.000000    0.600000   51.000000  1264.630000
#
#           Score_B      Risk_B        TOTAL     numbers   Score_B.1  \
# count  776.000000  776.000000   776.000000  776.000000  776.000000
# mean     0.313144    6.334008    13.218481    5.067655    0.223711
# std      0.169804   30.072845    51.312829    0.264449    0.080352
# min      0.200000    0.000000     0.000000    5.000000    0.200000
# ...

# %%
audit.shape
# Out:
# (776, 27)

# %%
audit.drop(['Sector_score','LOCATION_ID'],axis=1).head()
# Out:
#    PARA_A  Score_A  Risk_A  PARA_B  Score_B  Risk_B  TOTAL  numbers  \
# 0    4.18      0.6   2.508    2.50      0.2   0.500   6.68      5.0
# 1    0.00      0.2   0.000    4.83      0.2   0.966   4.83      5.0
# 2    0.51      0.2   0.102    0.23      0.2   0.046   0.74      5.0
# 3    0.00      0.2   0.000   10.80      0.6   6.480  10.80      6.0
# 4    0.00      0.2   0.000    0.08      0.2   0.016   0.08      5.0
#
#    Score_B.1  Risk_C  ...   RiSk_E  History  Prob  Risk_F  Score  \
# 0        0.2     1.0  ...      0.4        0   0.2     0.0    2.4
# 1        0.2     1.0  ...      0.4        0   0.2     0.0    2.0
# 2        0.2     1.0  ...      0.4        0   0.2     0.0    2.0
# 3        0.6     3.6  ...      0.4        0   0.2     0.0    4.4
# 4        0.2     1.0  ...      0.4        0   0.2     0.0    2.0
#
#    Inherent_Risk  CONTROL_RISK  Detection_Risk  Audit_Risk  Risk
# 0          8.574           0.4             0.5      1.7148     1
# ...

# %%
#X = audit.drop('Sector_score',axis=1)
X =audit.drop(['Sector_score','LOCATION_ID'],axis=1) #LOCATION_ID这一列当中有的值是字符，不能做数值标准化运算，把它也去掉
#y = audit['Sector_score']
y = audit['District_Loss']  #应变量这一列因为是属于分类项，所以需要这一列的值是整数的，不能有小数的，比如可 选 District_Loss 这1列

# %%
X.describe().transpose().shape
# Out:
# (25, 8)

# %%
X.shape
# Out:
# (776, 25)

# %%
X.isnull().describe()
# Out:
#        PARA_A Score_A Risk_A PARA_B Score_B Risk_B  TOTAL numbers Score_B.1  \
# count     776     776    776    776     776    776    776     776       776
# unique      1       1      1      1       1      1      1       1         1
# top     False   False  False  False   False  False  False   False     False
# freq      776     776    776    776     776    776    776     776       776
#
#        Risk_C  ...   RiSk_E History   Prob Risk_F  Score Inherent_Risk  \
# count     776  ...      776     776    776    776    776           776
# unique      1  ...        1       1      1      1      1             1
# top     False  ...    False   False  False  False  False         False
# freq      776  ...      776     776    776    776    776           776
#
#        CONTROL_RISK Detection_Risk Audit_Risk   Risk
# count           776            776        776    776
# unique            1              1          1      1
# top           False          False      False  False
# ...

# %%
X.isnull().any() #Money_Value列有缺失值，也不能进行数据标准化运算
# Out:
# PARA_A            False
# Score_A           False
# Risk_A            False
# PARA_B            False
# Score_B           False
# Risk_B            False
# TOTAL             False
# numbers           False
# Score_B.1         False
# Risk_C            False
# Money_Value        True
# Score_MV          False
# Risk_D            False
# District_Loss     False
# PROB              False
# RiSk_E            False
# History           False
# Prob              False
# Risk_F            False
# Score             False
# Inherent_Risk     False
# CONTROL_RISK      False
# Detection_Risk    False
# Audit_Risk        False
# Risk              False
# dtype: bool

# %%
X=X.fillna(X.mean()) # 用平均值对缺失值 进行填充

# %%
X.isnull().any() #再次检查发现Money_Value列没有缺失值了
# Out:
# PARA_A            False
# Score_A           False
# Risk_A            False
# PARA_B            False
# Score_B           False
# Risk_B            False
# TOTAL             False
# numbers           False
# Score_B.1         False
# Risk_C            False
# Money_Value       False
# Score_MV          False
# Risk_D            False
# District_Loss     False
# PROB              False
# RiSk_E            False
# History           False
# Prob              False
# Risk_F            False
# Score             False
# Inherent_Risk     False
# CONTROL_RISK      False
# Detection_Risk    False
# Audit_Risk        False
# Risk              False
# dtype: bool

# %%
y.isnull().any() #
# Out:
# False

# %%
#下面就可以进行标准化

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
#scaler = StandardScaler(copy=True, with_mean=True, with_std=True)
scaler.fit(X_train)

X_train = scaler.transform(X_train)

X_test = scaler.transform(X_test)


X_test
# Out:
# array([[-0.39668852, -0.84213153, -0.36086913, ...,  0.        ,
#         -0.31629265, -0.77105159],
#        [ 0.1802855 ,  1.49734603,  0.21129462, ...,  0.        ,
#          0.22466143,  1.29693009],
#        [ 0.21544736,  1.49734603,  0.24616333, ...,  0.        ,
#         -0.31418041, -0.77105159],
#        ...,
#        [-0.04826653,  1.49734603, -0.01535196, ...,  0.        ,
#         -0.21367048,  1.29693009],
#        [ 0.71090982,  1.49734603,  0.73749508, ...,  0.        ,
#          0.34215161,  1.29693009],
#        [ 2.67358047,  1.49734603,  2.6838028 , ...,  0.        ,
#          0.26010325,  1.29693009]])

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp = MLPClassifier(hidden_layer_sizes=(5,4,3),max_iter=500)

# %%
print (X_train[0])
print (type(y_train)) #Serries

mlp.fit(X_train,y_train)
# Out:
# [-0.39668852 -0.84213153 -0.36086913 -0.42006143 -0.66889761 -0.40706415
#  -0.46966325 -0.24389106 -0.28754306 -0.27638815 -0.19555063 -0.55042026
#  -0.19051504 -0.3907652  -0.17679549 -0.39430358 -0.20222914 -0.2267126
#  -0.18226436 -0.80478816 -0.29833389 -0.39796776  0.         -0.34646758
#  -0.77105159]
# <class 'pandas.core.series.Series'>
# C:\Users\yuli\AppData\Local\Continuum\Anaconda3\envs\Python35\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(5, 4, 3), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=500, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
# ...

# %%
predictions = mlp.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

print(confusion_matrix(y_test,predictions))
# Out:
# [[155   0   1]
#  [  0  10   2]
#  [  0   0  26]]

# %%
print(classification_report(y_test,predictions))
# Out:
#              precision    recall  f1-score   support
#
#           2       1.00      0.99      1.00       156
#           4       1.00      0.83      0.91        12
#           6       0.90      1.00      0.95        26
#
# avg / total       0.99      0.98      0.98       194

# %%
print (mlp.coefs_)
# Out:
# [array([[  5.16820982e-01,   2.19488913e-01,  -6.97028719e-02,
#          -7.65904828e-01,  -3.91341289e-01],
#        [ -1.47476366e-01,  -1.22865122e-01,   3.80326054e-01,
#          -1.24257947e-01,   1.96735906e-01],
#        [ -2.97919841e-01,   2.52168174e-01,   3.07389619e-01,
#          -5.24934745e-01,   3.75861429e-01],
#        [  2.99282978e-01,  -8.87337291e-02,   1.05179927e-01,
#          -7.38200237e-01,  -3.37218082e-01],
#        [  1.76024802e-01,   1.83235249e-01,   4.97254916e-01,
#          -6.21227825e-01,   1.59665119e-01],
#        [ -3.82086961e-01,   1.17119691e-01,  -6.93332228e-02,
#          -1.53993195e-01,  -7.13549304e-01],
#        [  2.29711960e-01,   6.00990594e-02,   1.11689831e-01,
#          -7.95331155e-01,  -2.22720297e-03],
#        [  7.86452365e-02,  -9.91059720e-02,  -2.03994357e-01,
#          -2.01587241e-01,  -5.72819384e-01],
#        [  6.48070526e-02,   5.92008562e-01,   3.84590968e-01,
#          -7.43444827e-01,  -3.93314004e-01],
# ...

# %%
print (mlp.coefs_[0])
# Out:
# [[  5.16820982e-01   2.19488913e-01  -6.97028719e-02  -7.65904828e-01
#    -3.91341289e-01]
#  [ -1.47476366e-01  -1.22865122e-01   3.80326054e-01  -1.24257947e-01
#     1.96735906e-01]
#  [ -2.97919841e-01   2.52168174e-01   3.07389619e-01  -5.24934745e-01
#     3.75861429e-01]
#  [  2.99282978e-01  -8.87337291e-02   1.05179927e-01  -7.38200237e-01
#    -3.37218082e-01]
#  [  1.76024802e-01   1.83235249e-01   4.97254916e-01  -6.21227825e-01
#     1.59665119e-01]
#  [ -3.82086961e-01   1.17119691e-01  -6.93332228e-02  -1.53993195e-01
#    -7.13549304e-01]
#  [  2.29711960e-01   6.00990594e-02   1.11689831e-01  -7.95331155e-01
#    -2.22720297e-03]
#  [  7.86452365e-02  -9.91059720e-02  -2.03994357e-01  -2.01587241e-01
#    -5.72819384e-01]
#  [  6.48070526e-02   5.92008562e-01   3.84590968e-01  -7.43444827e-01
#    -3.93314004e-01]
#  [  2.59951069e-01  -9.71097857e-02  -3.30943994e-02  -4.01574047e-01
#    -6.77568035e-01]
# ...

# %%
print (mlp.coefs_[1])
# Out:
# [[-0.51844577  0.02742621  0.05228986  0.37016918]
#  [-0.18342178 -0.41114182  1.19802143 -0.07928227]
#  [-0.06721889  1.14031246 -0.4317476   0.7157058 ]
#  [-0.09326477  0.85195229 -0.96842355 -0.38050632]
#  [ 0.37031784  0.51154489 -1.00736023  0.63600279]]

# %%
print (mlp.coefs_[2])
# Out:
# [[-0.47128026 -0.31064087  0.24930073]
#  [ 1.22612586 -0.18483357 -0.71974124]
#  [-0.97716278 -0.32499984  1.01181358]
#  [ 0.35423661  0.58335991 -0.4715755 ]]

# %%
print (mlp.coefs_[3])
# Out:
# [[ 0.27750971 -0.9069612  -1.12172503]
#  [-0.30049737  0.78738096  0.49164172]
#  [-1.4983389  -0.34063597 -0.06504866]]

# %%
print (mlp.intercepts_[0])
# Out:
# [ 0.19996338  0.4578823   0.20106698  0.56603394  0.64309957]
